# %%
import numpy as np
import statsmodels.api as sm
from matplotlib import pyplot as plt
from scipy.stats import norm,beta

# %% [markdown]
# $\frac{a-1}{a+b-2}=F(x_0)$, $a+b=C(100)$; $a=(C-2)F(x_0)+1$, $b=C-a$.

# %%
size=10000
C=120
samples=np.sort(norm.rvs(size=size))
cdf=np.linspace(0,1,size)
x0=1
Fx0=np.interp(x0,samples,cdf)
a=(C-2)*Fx0+1
b=C-a
par=norm.pdf(x=x0)
print('a =',a,'b =',b)

X=sm.add_constant(samples)
y=cdf
weights=beta.pdf(x=cdf,a=a,b=b)
fit=sm.WLS(y,X,weights).fit()
params=fit.params
est=params[1]
print('parameter:',par)
print('estimation:',est)

plt.plot(samples,cdf,label='emp cdf')
plt.plot(weights+samples.min(),cdf,label='weights')
plt.plot(samples,fit.model.predict(params),label='prediction')
plt.plot([x0,x0,samples.min()],[0,Fx0,Fx0],label='point')
plt.xlim([samples.min()-0.5,samples.max()+0.5])
plt.ylim([0-0.05,1+0.05])
plt.legend()
plt.show()
# Out:
# a = 100.29674221147651 b = 19.703257788523487
# parameter: 0.24197072451914337
# estimation: 0.25772848950133165
